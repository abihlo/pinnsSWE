# %%
# !pip install pyDOE
# !pip install tensorflow_addons
# Out:
# Collecting pyDOE
#   Downloading https://files.pythonhosted.org/packages/bc/ac/91fe4c039e2744466621343d3b8af4a485193ed0aab53af5b1db03be0989/pyDOE-0.3.8.zip
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from pyDOE) (1.4.1)
# Building wheels for collected packages: pyDOE
#   Building wheel for pyDOE (setup.py) ... done
#   Created wheel for pyDOE: filename=pyDOE-0.3.8-cp37-none-any.whl size=18178 sha256=e44360772e504c89f4effb21d5cc15599f85229abee046d12e3ffa14e896c7b2
#   Stored in directory: /root/.cache/pip/wheels/7c/c8/58/a6493bd415e8ba5735082b5e0c096d7c1f2933077a8ce34544
# Successfully built pyDOE
# Installing collected packages: pyDOE
# Successfully installed pyDOE-0.3.8
# Collecting tensorflow_addons
#   Downloading https://files.pythonhosted.org/packages/74/e3/56d2fe76f0bb7c88ed9b2a6a557e25e83e252aec08f13de34369cd850a0b/tensorflow_addons-0.12.1-cp37-cp37m-manylinux2010_x86_64.whl (703kB)
#      |████████████████████████████████| 706kB 5.8MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.12.1

# %%
import tensorflow as tf
import tensorflow_addons as tfa
import numpy as np
from pyDOE import lhs
import matplotlib.pyplot as plt 
import imageio
import os
from google.colab import files

plt.rcParams.update({'font.size': 14})
tf.keras.backend.set_floatx('float64')

# %%
# Gravitational constant
g = tf.constant(9.80616, dtype=tf.float64)

# Radius of Earth
a = tf.constant(6.37122e6, dtype=tf.float64)

# Angular velocity
Omega = tf.constant(7.292e-5, dtype=tf.float64)

# %%
# Scales of problem
T = 86400
L = a.numpy()
U = L/T
HH = a.numpy()**2/(T**2*g.numpy())

# %%
# Choose one of the Williamson test cases
williamson = 6

# %% [markdown]
# ### Initial conditions

# %%
if williamson==2: # (Nonlinear geostrophic flow)
  
  days = 5
  c = 1.0
  H = c*HH
  alpha, R, lmbd0, tht0 = 0.0, a.numpy()/3, 3*np.pi/2, 0
  u00, h00 = 2*np.pi*a.numpy()/(12*86400), 2.94e4
  v00 = u00

  u0 = lambda lmbd, tht: u00*(np.cos(tht)*np.cos(alpha)+np.sin(tht)*np.cos(lmbd)*np.sin(alpha))/U
  v0 = lambda lmbd, tht: -v00*np.sin(lmbd)*np.sin(alpha)/U
  h0 = lambda lmbd, tht: (h00 - (a.numpy()*Omega.numpy()*u00+u00**2/2)*(-np.cos(lmbd)*np.cos(tht)*np.sin(alpha)+np.sin(tht)*np.cos(alpha))**2)/g.numpy()/H
  hs0 = lambda lmbd, tht: tf.sin(0.0*lmbd) + tf.sin(0.0*tht)

elif williamson==5: # (Flow over mountain)

  days = 15
  c = 20
  H = c*HH
  alpha, R, lmbd0, tht0 = 0.0, tf.constant(np.pi/9, dtype=tf.float64), 3*np.pi/2-2*np.pi, np.pi/6
  u00, h00, hs00 = 20, 5960, 2000
  v00 = u00

  u0 = lambda lmbd, tht: u00*(np.cos(tht)*np.cos(alpha)+np.sin(tht)*np.cos(lmbd)*np.sin(alpha))/U
  v0 = lambda lmbd, tht: -v00*np.sin(lmbd)*np.sin(alpha)/U
  
  r =  lambda lmbd, tht: tf.sqrt(tf.minimum(R**2, (lmbd-lmbd0)**2+(tht-tht0)**2))
  hs0 = lambda lmbd, tht: hs00*(1.0-r(lmbd,tht)/R)/H
  h0 = lambda lmbd, tht: (g.numpy()*h00 - (a.numpy()*Omega.numpy()*u00+u00**2/2)*(-np.cos(lmbd)*np.cos(tht)*np.sin(alpha)+np.sin(tht)*np.cos(alpha))**2)/g.numpy()/H
  
elif williamson==6: # (Rossby-Haurwitz wave)

  days = 14
  c = 20
  H = c*HH
  omega, R = 7.848e-6, 4
  K, h00 = omega, 8000
  
  u0 = lambda lmbd, tht: (a.numpy()*omega*np.cos(tht) + a.numpy()*K*np.cos(tht)**(R-1)*(R*np.sin(tht)**2-np.cos(tht)**2)*np.cos(R*lmbd))/U
  v0 = lambda lmbd, tht: -a.numpy()*K*R*np.cos(tht)**(R-1)*np.sin(tht)*np.sin(R*lmbd)/U

  A = lambda tht: omega/2*(2*Omega.numpy()+omega)*np.cos(tht)**2+0.25*K**2*np.cos(tht)**(2*R)*((R+1)*np.cos(tht)**2 + (2*R**2-R-2)-2*R**2*np.cos(tht)**(-2))
  B = lambda tht: 2*(Omega.numpy()+omega)*K/(R+1)/(R+2)*np.cos(tht)**R*((R**2+2*R+2) - (R+1)**2*np.cos(tht)**2)
  C = lambda tht: 0.25*K**2*np.cos(tht)**(2*R)*((R+1)*np.cos(tht)**2 - (R+2))
  h0 = lambda lmbd, tht: (g.numpy()*h00 + a.numpy()**2*A(tht)+a.numpy()**2*B(tht)*np.cos(R*lmbd)+a.numpy()**2*C(tht)*np.cos(2*R*lmbd))/g.numpy()/H
  hs0 = lambda lmbd, tht: tf.sin(0.0*lmbd) + tf.sin(0.0*tht)

# %% [markdown]
# ### Plot initial conditions

# %%
# Boundaries of the computational domain
lmbdleft, lmbdright = -np.pi, np.pi
thtlower, thtupper = -np.pi/2, np.pi/2
t0, tfinal = 0, days*86400/T

# %%
# Plot initial solution
x = np.linspace(lmbdleft, lmbdright, 100)
y = np.linspace(thtlower, thtupper, 100)
X, Y = np.meshgrid(x, y)
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.contourf(360/2/np.pi*X, 360/2/np.pi*Y, H*h0(X,Y), 100, cmap=plt.cm.coolwarm)
plt.colorbar()

plt.subplot(132)
plt.contourf(360/2/np.pi*X, 360/2/np.pi*Y, U*u0(X,Y), 100, cmap=plt.cm.coolwarm)
plt.colorbar()

plt.subplot(133)
plt.contourf(360/2/np.pi*X, 360/2/np.pi*Y, v0(X,Y), 100, cmap=plt.cm.coolwarm)
plt.colorbar()
plt.show()

# %% [markdown]
# ### Subclassing layers

# %%
class PeriodicSphere(tf.keras.layers.Layer):
  def __init__(self, name=None, **kwargs):
    super(PeriodicSphere, self).__init__(name=name)
    super(PeriodicSphere, self).__init__(**kwargs)

  def call(self, inputs):
    return tf.concat((tf.cos(inputs[1])*tf.cos(inputs[0]),
               tf.cos(inputs[1])*tf.sin(inputs[0]),
               tf.sin(inputs[1])), axis=1)

# %%
# Define the normalization layer
class Normalize(tf.keras.layers.Layer):
  def __init__(self, xmin, xmax, name=None, **kwargs):
    super(Normalize, self).__init__(name=name)
    self.xmin = xmin
    self.xmax = xmax
    super(Normalize, self).__init__(**kwargs)

  def call(self, inputs):
    return 2.0*(inputs-self.xmin)/(self.xmax-self.xmin)-1.0

  def get_config(self):
    config = super(Normalize, self).get_config()
    config.update({'xmin': self.xmin, 'xmax': self.xmax})
    return config

# %% [markdown]
# ### Define the network

# %%
def build_model(t0, tfinal, n_units=80, n_layers=8, summary=False):

  # Define the network
  inp1 = tf.keras.layers.Input(shape=(1,))
  b1 = Normalize(t0, tfinal)(inp1)

  inp2 = tf.keras.layers.Input(shape=(1,))
  inp3 = tf.keras.layers.Input(shape=(1,))
  b23 = PeriodicSphere()([inp2, inp3])

  b = tf.keras.layers.Concatenate()([b1, b23])

  for i in range(n_layers):
    b = tf.keras.layers.Dense(n_units, 'tanh', kernel_initializer='glorot_normal')(b)
  out = tf.keras.layers.Dense(3, activation='linear')(b)

  model = tf.keras.models.Model([inp1, inp2, inp3], out)
  
  if summary:
    model.summary()

  return model

# %% [markdown]
# ### Main NN training function

# %%
@tf.function
def train_network(pdes, inits, hs0, c, model):
                          
  # -------------- Training loop -----------------------

  # PDE points and associated self-adaptation weights
  t_pde, x_pde, y_pde, f = pdes[:,:1], pdes[:,1:2], pdes[:,2:3], pdes[:,3:4]

  # Initial value points and associated self-adaptation weights
  t_init, x_init, y_init = inits[:,:1], inits[:,1:2], inits[:,2:3]
  u_init, v_init, h_init =inits[:,3:4], inits[:,4:5], inits[:,5:6]

  # ----------- Train the network ----------------

  # Outer gradient for tuning network parameters
  with tf.GradientTape(persistent=True) as tape:

    # Inner gradient for derivatives of u wrt x and t
    with tf.GradientTape(persistent=True) as tape2:
          
      tape2.watch(t_pde), tape2.watch(x_pde), tape2.watch(y_pde)
          
      uvh = model([t_pde, x_pde, y_pde], training=True)
      u, v, h = uvh[:,:1], uvh[:,1:2], uvh[:,2:]
      hs = h - hs0(x_pde, y_pde)
      vcostht = v*tf.cos(y_pde)

    # Derivatives needed to define the SWE
    [dudt, dudx, dudy] = tape2.gradient(u, [t_pde, x_pde, y_pde])
    [dvdt, dvdx, dvdy] = tape2.gradient(v, [t_pde, x_pde, y_pde])
    [dhdt, dhdx, dhdy] = tape2.gradient(h, [t_pde, x_pde, y_pde])
    [dhsdx, dhsdy] = tape2.gradient(hs, [x_pde, y_pde])
    [dvcosthtdy] = tape2.gradient(vcostht, [y_pde])

    #  Solve the shallow-water equations
    eqnu = dudt + u/tf.cos(y_pde)*dudx + v*dudy - (f+u*tf.tan(y_pde))*v + c/tf.cos(y_pde)*dhdx
    eqnv = dvdt + u/tf.cos(y_pde)*dvdx + v*dvdy + (f+u*tf.tan(y_pde))*u + c*dhdy
    eqnh = dhdt + u/tf.cos(y_pde)*dhsdx + v*dhsdy + hs/tf.cos(y_pde)*(dudx + dvcosthtdy) 

    # Define the PDE loss  
    PDEloss_u = tf.reduce_mean(tf.square(eqnu))
    PDEloss_v = tf.reduce_mean(tf.square(eqnv))
    PDEloss_h = tf.reduce_mean(tf.square(eqnh))

    PDEloss = PDEloss_u + PDEloss_v + PDEloss_h

    # Define the initial value loss
    uvh_init_pred = model([t_init, x_init, y_init], training=True)
    u_init_pred, v_init_pred, h_init_pred = uvh_init_pred[:,:1], uvh_init_pred[:,1:2], uvh_init_pred[:,2:] 
        
    ICloss_u = tf.reduce_mean(tf.square(u_init-u_init_pred))
    ICloss_v = tf.reduce_mean(tf.square(v_init-v_init_pred))
    ICloss_h = tf.reduce_mean(tf.square(h_init-h_init_pred))

    ICloss = ICloss_u + ICloss_v + ICloss_h                  

  # Compute loss weighting
  gradPDE = tape.gradient(PDEloss, model.trainable_variables)
  gradIVP = tape.gradient(ICloss, model.trainable_variables)
  gradPDE_f = tf.concat([tf.reshape(p, [-1]) for p in gradPDE], axis=0)
  gradIVP_f = tf.concat([tf.reshape(p, [-1]) for p in gradIVP], axis=0)

  # Project conflicting gradients
  if tf.reduce_sum(tf.multiply(gradIVP_f, gradPDE_f)) < 0:
    if tf.random.uniform([1]) < 0.5:
      proj = tf.reduce_sum(tf.multiply(gradPDE_f, gradIVP_f))/tf.reduce_sum(tf.square(gradIVP_f))
      gradPDE = [gPDE - proj*gIVP for gPDE, gIVP in zip(gradPDE, gradIVP)]
    else:
      proj = tf.reduce_sum(tf.multiply(gradPDE_f, gradIVP_f))/tf.reduce_sum(tf.square(gradPDE_f))
      gradIVP = [gIVP - proj*gPDE for gPDE, gIVP in zip(gradPDE, gradIVP)]

  # Compute the gradient of the global loss wrt the model parameters
  grads = [gPDE+gIVP for gPDE, gIVP in zip(gradPDE, gradIVP)]
    
  return PDEloss, ICloss, grads

# %% [markdown]
# ### Define the collocation points

# %%
def defineCollocationPoints(t_bdry, x_bdry, y_bdry, u0, v0, h0, N_pde=50000, N_iv=10000):

  # Convert input to numpy array
  t_bdry, x_bdry, y_bdry = np.array(t_bdry), np.array(x_bdry), np.array(y_bdry)
  
  # Uniform random sampling on a sphere
  txy_min = np.array([t_bdry[0], x_bdry[0], 0])
  txy_max = np.array([t_bdry[1], x_bdry[1], 1])  
  pde_points = txy_min + (txy_max - txy_min)*lhs(3, N_pde)
  t_pde = pde_points[:, 0] 
  x_pde = pde_points[:, 1]
  y_pde = np.arccos(1-2*pde_points[:, 2]) + y_bdry[0]

  f = 2*Omega*T*np.sin(y_pde)
  
  # Stack all the PDE point data together
  pdes = np.column_stack([t_pde, x_pde, y_pde, f]).astype(np.float64)
  pdes = pdes[np.argsort(pdes[:,0])]  

  # Uniform random sampling on a sphere for initial values
  init_points = txy_min[1:] + (txy_max[1:] - txy_min[1:])*lhs(2, N_iv)
  x_init = init_points[:, 0]
  y_init = np.arccos(1-2*init_points[:, 1]) + y_bdry[0]
  t_init = t_bdry[0]+0*x_init

  # Stack all the ivp data together
  inits = np.column_stack([t_init, x_init, y_init]).astype(np.float64)

  return (pdes, f, inits)

# %%
N_pde, N_iv = 100000, 10000
(pdes, f, inits) = defineCollocationPoints([t0, tfinal], [lmbdleft, lmbdright], [thtlower, thtupper], u0, v0, h0, N_pde, N_iv)

# %% [markdown]
# ### Main training routine

# %%
def PINNtrain(pde_points, f, inits, hs0, c, epochs=10000):

  N_pde, N_iv = len(pde_points), len(inits)

  # Batch sizes
  bs_pdes, bs_inits = N_pde//160, N_iv//80

  # Boundaries for the models
  # model_boundaries = [5000*i for i in range(epochs//5000+1)]
  model_boundaries = [15000*i for i in range(epochs//15000+1)]
  lr_model = [1e-3,1e-3/np.sqrt(10),1e-3/np.sqrt(10),1e-4,1e-4,1e-4,1e-4,1e-4]

  print(model_boundaries)
  print(lr_model)

  nr_boundaries = len(model_boundaries)-1
  k = 0

  # initial value points
  t_init, x_init, y_init = inits[:,0], inits[:,1], inits[:,2]

  epoch_loss = np.zeros(epochs)
  nr_batches = 0

  # Main training loop
  for i in range(epochs):

    # Train a new model
    if np.mod(i, model_boundaries[k]) == 0:
      k +=1

      # Generate the tf.Dataset for the initial data
      if k==1: # Use the actual initial conditions
        u_init = u0(x_init, y_init)
        v_init = v0(x_init, y_init)
        h_init = h0(x_init, y_init)
      else: # Use the previous model
        t_init = (k-1)*tfinal/nr_boundaries + 0*t_init
        uvh = model([np.expand_dims(t_init, axis=1), 
                     np.expand_dims(x_init, axis=1), 
                     np.expand_dims(y_init, axis=1)]) 
        u_init, v_init, h_init = uvh[:,0], uvh[:,1], uvh[:,2]  

        # Save the previous model
        fname = "model" + str(k-1) + ".h5"
        model.save(fname)

      inits = np.column_stack([t_init, x_init, y_init, u_init, v_init, h_init])

      ds_init = tf.data.Dataset.from_tensor_slices(inits)
      ds_init = ds_init.cache().shuffle(N_iv).batch(bs_inits)
  
      # Generate the tf.Dataset for the collocation points
      N_ds = k*N_pde//nr_boundaries
      N_ds_ = (k-1)*N_pde//nr_boundaries
      pts = pde_points[N_ds_:N_ds]
      t_min, t_max = pts[:,0].min(), pts[:,0].max()

      ds_pde = tf.data.Dataset.from_tensor_slices(pde_points[N_ds_:N_ds])
      ds_pde = ds_pde.cache().shuffle(N_ds-N_ds_).batch(bs_pdes)
      ds = tf.data.Dataset.zip((ds_pde, ds_init))
      ds = ds.prefetch(tf.data.experimental.AUTOTUNE)

      # Generate a new model
      opt = tf.keras.optimizers.Adam(lr_model[k-1])
      model = build_model(t_min, t_max) 

      # Copy over weights from old model
      if k>1:
        print("Copy over weights from previous model...")
        fname = "model" + str(k-1) + ".h5"
        model_ = tf.keras.models.load_model(fname, custom_objects={'Normalize': Normalize, 
                                                                   'PeriodicSphere': PeriodicSphere})
        model.set_weights(model_.get_weights())

      print("\nTraining model no. {} for initial time {: 4.2f}, running over interval [{: 4.2f},{: 4.2f}] with lr={}.\n".format(k, t_init[0], t_min, t_max, lr_model[k-1]))

    # Training for that epoch
    for (pdes, inits) in ds:

      # Train the network
      PDEloss, ICloss, grads = train_network(pdes, inits, hs0, c, model)

      # Gradient step
      opt.apply_gradients(zip(grads, model.trainable_variables))

      epoch_loss[i] += PDEloss + ICloss
      nr_batches += 1

    # Get total epoch loss
    epoch_loss[i] /= nr_batches
    nr_batches = 0

    if (np.mod(i, 100)==0):
      print("PDE loss, IV loss in {}th epoch: {: 6.4f}, {: 6.4f}.".format(i, PDEloss, ICloss))

  # Add the last model
  fname = "model" + str(k) + ".h5"
  model.save(fname)

  return epoch_loss, k

# %% [markdown]
# ### Train and visualize

# %%
epochs = 75000
loss, nr_models = PINNtrain(pdes, f, inits, hs0, c, epochs)
# Out:
# [0, 15000, 30000, 45000, 60000, 75000]
# [0.001, 0.00031622776601683794, 0.00031622776601683794, 0.0001, 0.0001, 0.0001, 0.0001, 0.0001]
#
# Training model no. 1 for initial time  0.00, running over interval [ 0.00, 2.80] with lr=0.001.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: RuntimeWarning: divide by zero encountered in remainder
# PDE loss, IV loss in 0th epoch:  0.2038,  0.6976.
# PDE loss, IV loss in 100th epoch:  0.0198,  0.2709.
# PDE loss, IV loss in 200th epoch:  0.0253,  0.2347.
# PDE loss, IV loss in 300th epoch:  0.0254,  0.0034.
# PDE loss, IV loss in 400th epoch:  0.0293,  0.0021.
# PDE loss, IV loss in 500th epoch:  0.0248,  0.0018.
# PDE loss, IV loss in 600th epoch:  0.0147,  0.0009.
# PDE loss, IV loss in 700th epoch:  0.0288,  0.0008.
# PDE loss, IV loss in 800th epoch:  0.0102,  0.0005.
# PDE loss, IV loss in 900th epoch:  0.0113,  0.0009.
# PDE loss, IV loss in 1000th epoch:  0.0141,  0.0008.
# PDE loss, IV loss in 1100th epoch:  0.0355,  0.0016.
# PDE loss, IV loss in 1200th epoch:  0.0092,  0.0005.
# PDE loss, IV loss in 1300th epoch:  0.0068,  0.0003.
# PDE loss, IV loss in 1400th epoch:  0.0100,  0.0006.
# PDE loss, IV loss in 1500th epoch:  0.0201,  0.0008.
# PDE loss, IV loss in 1600th epoch:  0.0068,  0.0003.
# PDE loss, IV loss in 1700th epoch:  0.0089,  0.0004.
# PDE loss, IV loss in 1800th epoch:  0.0075,  0.0003.
# PDE loss, IV loss in 1900th epoch:  0.0044,  0.0002.
# PDE loss, IV loss in 2000th epoch:  0.0043,  0.0001.
# PDE loss, IV loss in 2100th epoch:  0.0095,  0.0003.
# PDE loss, IV loss in 2200th epoch:  0.0021,  0.0001.
# PDE loss, IV loss in 2300th epoch:  0.0049,  0.0003.
# PDE loss, IV loss in 2400th epoch:  0.0046,  0.0002.
# PDE loss, IV loss in 2500th epoch:  0.0078,  0.0002.
# PDE loss, IV loss in 2600th epoch:  0.0045,  0.0002.
# PDE loss, IV loss in 2700th epoch:  0.0051,  0.0001.
# PDE loss, IV loss in 2800th epoch:  0.0052,  0.0003.
# PDE loss, IV loss in 2900th epoch:  0.0055,  0.0001.
# PDE loss, IV loss in 3000th epoch:  0.0036,  0.0001.
# PDE loss, IV loss in 3100th epoch:  0.0064,  0.0001.
# PDE loss, IV loss in 3200th epoch:  0.0099,  0.0002.
# PDE loss, IV loss in 3300th epoch:  0.0118,  0.0004.
# PDE loss, IV loss in 3400th epoch:  0.0039,  0.0001.
# PDE loss, IV loss in 3500th epoch:  0.0101,  0.0001.
# PDE loss, IV loss in 3600th epoch:  0.0019,  0.0001.
# PDE loss, IV loss in 3700th epoch:  0.0031,  0.0001.
# PDE loss, IV loss in 3800th epoch:  0.0030,  0.0001.
# PDE loss, IV loss in 3900th epoch:  0.0024,  0.0002.
# PDE loss, IV loss in 4000th epoch:  0.0020,  0.0001.
# PDE loss, IV loss in 4100th epoch:  0.0101,  0.0002.
# PDE loss, IV loss in 4200th epoch:  0.0035,  0.0001.
# PDE loss, IV loss in 4300th epoch:  0.0021,  0.0003.
# PDE loss, IV loss in 4400th epoch:  0.0075,  0.0003.
# PDE loss, IV loss in 4500th epoch:  0.0013,  0.0001.
# PDE loss, IV loss in 4600th epoch:  0.0054,  0.0002.
# PDE loss, IV loss in 4700th epoch:  0.0026,  0.0001.
# PDE loss, IV loss in 4800th epoch:  0.0047,  0.0001.
# PDE loss, IV loss in 4900th epoch:  0.0020,  0.0001.
# PDE loss, IV loss in 5000th epoch:  0.0015,  0.0001.
# PDE loss, IV loss in 5100th epoch:  0.0018,  0.0001.
# PDE loss, IV loss in 5200th epoch:  0.0027,  0.0003.
# PDE loss, IV loss in 5300th epoch:  0.0063,  0.0002.
# PDE loss, IV loss in 5400th epoch:  0.0085,  0.0001.
# PDE loss, IV loss in 5500th epoch:  0.0028,  0.0000.
# PDE loss, IV loss in 5600th epoch:  0.0025,  0.0002.
# PDE loss, IV loss in 5700th epoch:  0.0037,  0.0001.
# PDE loss, IV loss in 5800th epoch:  0.0052,  0.0001.
# PDE loss, IV loss in 5900th epoch:  0.0028,  0.0001.
# PDE loss, IV loss in 6000th epoch:  0.0019,  0.0001.
# PDE loss, IV loss in 6100th epoch:  0.0036,  0.0001.
# PDE loss, IV loss in 6200th epoch:  0.0052,  0.0001.
# PDE loss, IV loss in 6300th epoch:  0.0022,  0.0001.
# PDE loss, IV loss in 6400th epoch:  0.0082,  0.0001.
# PDE loss, IV loss in 6500th epoch:  0.0012,  0.0000.
# PDE loss, IV loss in 6600th epoch:  0.0011,  0.0000.
# PDE loss, IV loss in 6700th epoch:  0.0016,  0.0001.
# PDE loss, IV loss in 6800th epoch:  0.0011,  0.0001.
# PDE loss, IV loss in 6900th epoch:  0.0013,  0.0000.
# PDE loss, IV loss in 7000th epoch:  0.0017,  0.0000.
# PDE loss, IV loss in 7100th epoch:  0.0031,  0.0001.
# PDE loss, IV loss in 7200th epoch:  0.0055,  0.0001.
# PDE loss, IV loss in 7300th epoch:  0.0025,  0.0001.
# PDE loss, IV loss in 7400th epoch:  0.0066,  0.0001.
# PDE loss, IV loss in 7500th epoch:  0.0020,  0.0003.
# PDE loss, IV loss in 7600th epoch:  0.0013,  0.0000.
# PDE loss, IV loss in 7700th epoch:  0.0012,  0.0000.
# PDE loss, IV loss in 7800th epoch:  0.0013,  0.0000.
# PDE loss, IV loss in 7900th epoch:  0.0011,  0.0000.
# PDE loss, IV loss in 8000th epoch:  0.0027,  0.0002.
# PDE loss, IV loss in 8100th epoch:  0.0017,  0.0001.
# PDE loss, IV loss in 8200th epoch:  0.0062,  0.0001.
# PDE loss, IV loss in 8300th epoch:  0.0019,  0.0001.
# PDE loss, IV loss in 8400th epoch:  0.0121,  0.0005.
# PDE loss, IV loss in 8500th epoch:  0.0031,  0.0001.
# PDE loss, IV loss in 8600th epoch:  0.0010,  0.0000.
# PDE loss, IV loss in 8700th epoch:  0.0045,  0.0001.
# PDE loss, IV loss in 8800th epoch:  0.0126,  0.0002.
# PDE loss, IV loss in 8900th epoch:  0.0124,  0.0003.
# PDE loss, IV loss in 9000th epoch:  0.0019,  0.0001.
# PDE loss, IV loss in 9100th epoch:  0.0134,  0.0002.
# PDE loss, IV loss in 9200th epoch:  0.0017,  0.0001.
# PDE loss, IV loss in 9300th epoch:  0.0019,  0.0001.
# PDE loss, IV loss in 9400th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 9500th epoch:  0.0033,  0.0010.
# PDE loss, IV loss in 9600th epoch:  0.0019,  0.0001.
# PDE loss, IV loss in 9700th epoch:  0.0029,  0.0001.
# PDE loss, IV loss in 9800th epoch:  0.0015,  0.0000.
# PDE loss, IV loss in 9900th epoch:  0.0018,  0.0001.
# PDE loss, IV loss in 10000th epoch:  0.0024,  0.0001.
# PDE loss, IV loss in 10100th epoch:  0.0018,  0.0001.
# PDE loss, IV loss in 10200th epoch:  0.0026,  0.0001.
# PDE loss, IV loss in 10300th epoch:  0.0017,  0.0000.
# PDE loss, IV loss in 10400th epoch:  0.0017,  0.0000.
# PDE loss, IV loss in 10500th epoch:  0.0022,  0.0001.
# PDE loss, IV loss in 10600th epoch:  0.0029,  0.0002.
# PDE loss, IV loss in 10700th epoch:  0.0025,  0.0001.
# PDE loss, IV loss in 10800th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 10900th epoch:  0.0051,  0.0001.
# PDE loss, IV loss in 11000th epoch:  0.0046,  0.0002.
# PDE loss, IV loss in 11100th epoch:  0.0011,  0.0000.
# PDE loss, IV loss in 11200th epoch:  0.0031,  0.0001.
# PDE loss, IV loss in 11300th epoch:  0.0019,  0.0000.
# PDE loss, IV loss in 11400th epoch:  0.0018,  0.0000.
# PDE loss, IV loss in 11500th epoch:  0.0014,  0.0000.
# PDE loss, IV loss in 11600th epoch:  0.0010,  0.0000.
# PDE loss, IV loss in 11700th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 11800th epoch:  0.0035,  0.0001.
# PDE loss, IV loss in 11900th epoch:  0.0014,  0.0001.
# PDE loss, IV loss in 12000th epoch:  0.0008,  0.0001.
# PDE loss, IV loss in 12100th epoch:  0.0008,  0.0000.
# PDE loss, IV loss in 12200th epoch:  0.0007,  0.0000.
# PDE loss, IV loss in 12300th epoch:  0.0009,  0.0000.
# PDE loss, IV loss in 12400th epoch:  0.0027,  0.0001.
# PDE loss, IV loss in 12500th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 12600th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 12700th epoch:  0.0019,  0.0001.
# PDE loss, IV loss in 12800th epoch:  0.0100,  0.0004.
# PDE loss, IV loss in 12900th epoch:  0.0027,  0.0001.
# PDE loss, IV loss in 13000th epoch:  0.0025,  0.0000.
# PDE loss, IV loss in 13100th epoch:  0.0015,  0.0000.
# PDE loss, IV loss in 13200th epoch:  0.0039,  0.0001.
# PDE loss, IV loss in 13300th epoch:  0.0013,  0.0000.
# PDE loss, IV loss in 13400th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 13500th epoch:  0.0028,  0.0001.
# PDE loss, IV loss in 13600th epoch:  0.0018,  0.0000.
# PDE loss, IV loss in 13700th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 13800th epoch:  0.0064,  0.0001.
# PDE loss, IV loss in 13900th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 14000th epoch:  0.0033,  0.0001.
# PDE loss, IV loss in 14100th epoch:  0.0035,  0.0001.
# PDE loss, IV loss in 14200th epoch:  0.0022,  0.0001.
# PDE loss, IV loss in 14300th epoch:  0.0023,  0.0001.
# PDE loss, IV loss in 14400th epoch:  0.0015,  0.0000.
# PDE loss, IV loss in 14500th epoch:  0.0028,  0.0001.
# PDE loss, IV loss in 14600th epoch:  0.0038,  0.0001.
# PDE loss, IV loss in 14700th epoch:  0.0012,  0.0001.
# PDE loss, IV loss in 14800th epoch:  0.0019,  0.0001.
# PDE loss, IV loss in 14900th epoch:  0.0014,  0.0000.
# Copy over weights from previous model...
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
#
# Training model no. 2 for initial time  2.80, running over interval [ 2.80, 5.60] with lr=0.00031622776601683794.
#
# PDE loss, IV loss in 15000th epoch:  0.0285,  0.1162.
# PDE loss, IV loss in 15100th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 15200th epoch:  0.0007,  0.0000.
# PDE loss, IV loss in 15300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 15400th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 15500th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 15600th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 15700th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 15800th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 15900th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 16000th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 16100th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 16200th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 16300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 16400th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 16500th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 16600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 16700th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 16800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 16900th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 17000th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 17100th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 17200th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 17300th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 17400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 17500th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 17600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 17700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 17800th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 17900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 18000th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 18100th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 18200th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 18300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 18400th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 18500th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 18600th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 18700th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 18800th epoch:  0.0008,  0.0000.
# PDE loss, IV loss in 18900th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 19000th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 19100th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 19200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 19300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 19400th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 19500th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 19600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 19700th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 19800th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 19900th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 20000th epoch:  0.0005,  0.0001.
# PDE loss, IV loss in 20100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 20200th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 20300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 20400th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 20500th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 20600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 20700th epoch:  0.0008,  0.0000.
# PDE loss, IV loss in 20800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 20900th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 21000th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 21100th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 21200th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 21300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 21400th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 21500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 21600th epoch:  0.0007,  0.0000.
# PDE loss, IV loss in 21700th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 21800th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 21900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 22000th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 22100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 22200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 22300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 22400th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 22500th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 22600th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 22700th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 22800th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 22900th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 23000th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 23100th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 23200th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 23300th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 23400th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 23500th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 23600th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 23700th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 23800th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 23900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 24000th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 24100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 24200th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 24300th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 24400th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 24500th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 24600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 24700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 24800th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 24900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 25000th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 25100th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 25200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 25300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 25400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 25500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 25600th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 25700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 25800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 25900th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 26000th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 26100th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 26200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 26300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 26400th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 26500th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 26600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 26700th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 26800th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 26900th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 27000th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 27100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 27200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 27300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 27400th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 27500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 27600th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 27700th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 27800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 27900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 28000th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 28100th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 28200th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 28300th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 28400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 28500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 28600th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 28700th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 28800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 28900th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 29000th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 29100th epoch:  0.0010,  0.0000.
# PDE loss, IV loss in 29200th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 29300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 29400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 29500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 29600th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 29700th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 29800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 29900th epoch:  0.0001,  0.0000.
# Copy over weights from previous model...
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
#
# Training model no. 3 for initial time  5.60, running over interval [ 5.60, 8.40] with lr=0.00031622776601683794.
#
# PDE loss, IV loss in 30000th epoch:  0.0259,  0.0784.
# PDE loss, IV loss in 30100th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 30200th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 30300th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 30400th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 30500th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 30600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 30700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 30800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 30900th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 31000th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 31100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 31200th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 31300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 31400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 31500th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 31600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 31700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 31800th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 31900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 32000th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 32100th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 32200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 32300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 32400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 32500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 32600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 32700th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 32800th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 32900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 33000th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 33100th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 33200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 33300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 33400th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 33500th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 33600th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 33700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 33800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 33900th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 34000th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 34100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 34200th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 34300th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 34400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 34500th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 34600th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 34700th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 34800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 34900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 35000th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 35100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 35200th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 35300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 35400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 35500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 35600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 35700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 35800th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 35900th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 36000th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 36100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 36200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 36300th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 36400th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 36500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 36600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 36700th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 36800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 36900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 37000th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 37100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 37200th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 37300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 37400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 37500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 37600th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 37700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 37800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 37900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 38000th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 38100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 38200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 38300th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 38400th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 38500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 38600th epoch:  0.0006,  0.0000.
# PDE loss, IV loss in 38700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 38800th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 38900th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 39000th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 39100th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 39200th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 39300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 39400th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 39500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 39600th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 39700th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 39800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 39900th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 40000th epoch:  0.0007,  0.0000.
# PDE loss, IV loss in 40100th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 40200th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 40300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 40400th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 40500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 40600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 40700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 40800th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 40900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 41000th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 41100th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 41200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 41300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 41400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 41500th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 41600th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 41700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 41800th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 41900th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 42000th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 42100th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 42200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 42300th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 42400th epoch:  0.0004,  0.0000.
# PDE loss, IV loss in 42500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 42600th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 42700th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 42800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 42900th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 43000th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 43100th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 43200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 43300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 43400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 43500th epoch:  0.0009,  0.0000.
# PDE loss, IV loss in 43600th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 43700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 43800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 43900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 44000th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 44100th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 44200th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 44300th epoch:  0.0003,  0.0000.
# PDE loss, IV loss in 44400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 44500th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 44600th epoch:  0.0005,  0.0000.
# PDE loss, IV loss in 44700th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 44800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 44900th epoch:  0.0003,  0.0000.
# Copy over weights from previous model...
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
#
# Training model no. 4 for initial time  8.40, running over interval [ 8.40, 11.20] with lr=0.0001.
#
# PDE loss, IV loss in 45000th epoch:  0.0131,  0.4049.
# PDE loss, IV loss in 45100th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 45200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 45300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 45400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 45500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 45600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 45700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 45800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 45900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 46000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 46100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 46200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 46300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 46400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 46500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 46600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 46700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 46800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 46900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 47000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 47100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 47200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 47300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 47400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 47500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 47600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 47700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 47800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 47900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 48000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 48100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 48200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 48300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 48400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 48500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 48600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 48700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 48800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 48900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 49000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 49100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 49200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 49300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 49400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 49500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 49600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 49700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 49800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 49900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 50000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 50100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 50200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 50300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 50400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 50500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 50600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 50700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 50800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 50900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 51000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 51100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 51200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 51300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 51400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 51500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 51600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 51700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 51800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 51900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 52000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 52100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 52200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 52300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 52400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 52500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 52600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 52700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 52800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 52900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 53000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 53100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 53200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 53300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 53400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 53500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 53600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 53700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 53800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 53900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 54000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 54100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 54200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 54300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 54400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 54500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 54600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 54700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 54800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 54900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 55000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 55100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 55200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 55300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 55400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 55500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 55600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 55700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 55800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 55900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 56000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 56100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 56200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 56300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 56400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 56500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 56600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 56700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 56800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 56900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 57000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 57100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 57200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 57300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 57400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 57500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 57600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 57700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 57800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 57900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 58000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 58100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 58200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 58300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 58400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 58500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 58600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 58700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 58800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 58900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 59000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 59100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 59200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 59300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 59400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 59500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 59600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 59700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 59800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 59900th epoch:  0.0000,  0.0000.
# Copy over weights from previous model...
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
#
# Training model no. 5 for initial time  11.20, running over interval [ 11.20, 14.00] with lr=0.0001.
#
# PDE loss, IV loss in 60000th epoch:  0.0118,  0.3713.
# PDE loss, IV loss in 60100th epoch:  0.0002,  0.0000.
# PDE loss, IV loss in 60200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 60300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 60400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 60500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 60600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 60700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 60800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 60900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 61000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 61100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 61200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 61300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 61400th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 61500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 61600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 61700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 61800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 61900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 62000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 62100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 62200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 62300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 62400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 62500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 62600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 62700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 62800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 62900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 63000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 63100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 63200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 63300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 63400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 63500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 63600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 63700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 63800th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 63900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 64000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 64100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 64200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 64300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 64400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 64500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 64600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 64700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 64800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 64900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 65000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 65100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 65200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 65300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 65400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 65500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 65600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 65700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 65800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 65900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 66000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 66100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 66200th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 66300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 66400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 66500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 66600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 66700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 66800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 66900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 67000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 67100th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 67200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 67300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 67400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 67500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 67600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 67700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 67800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 67900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 68000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 68100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 68200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 68300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 68400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 68500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 68600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 68700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 68800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 68900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 69000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 69100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 69200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 69300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 69400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 69500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 69600th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 69700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 69800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 69900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 70000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 70100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 70200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 70300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 70400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 70500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 70600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 70700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 70800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 70900th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 71000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 71100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 71200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 71300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 71400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 71500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 71600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 71700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 71800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 71900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 72000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 72100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 72200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 72300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 72400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 72500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 72600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 72700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 72800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 72900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 73000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 73100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 73200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 73300th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 73400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 73500th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 73600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 73700th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 73800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 73900th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 74000th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 74100th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 74200th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 74300th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 74400th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 74500th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 74600th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 74700th epoch:  0.0001,  0.0000.
# PDE loss, IV loss in 74800th epoch:  0.0000,  0.0000.
# PDE loss, IV loss in 74900th epoch:  0.0000,  0.0000.

# %%
def moving_average(x, w):
    return np.convolve(x, np.ones(w), 'valid') / w

# %%
steps = 101
plt.semilogy(range(steps//2, epochs-steps//2), moving_average(loss, steps))
plt.xlabel('Epochs')
plt.ylabel('Total loss')
plt.grid()

fname = 'Loss_Williamson_' + str(williamson) + '_epochs' + str(epochs) + '.png'
plt.savefig(fname)
files.download(fname)

# %%
# Composite prediction function
def predict(nr_models,t,x,y):
  
  total_steps = len(t)
  steps_per_model = total_steps//nr_models
  u = np.zeros((total_steps, 1))
  v = np.zeros((total_steps, 1)) 
  h = np.zeros((total_steps, 1))
  uy = np.zeros((total_steps, 1))
  vx = np.zeros((total_steps, 1)) 

  for i in range(nr_models):
    curr_model = "model" + str(i+1) + '.h5'
    model = tf.keras.models.load_model(curr_model, custom_objects={'Normalize': Normalize, 
                                                                   'PeriodicSphere': PeriodicSphere})
    
    tt = tf.Variable(t[i*steps_per_model:(i+1)*steps_per_model,])
    xx = tf.Variable(x[i*steps_per_model:(i+1)*steps_per_model,])
    yy = tf.Variable(y[i*steps_per_model:(i+1)*steps_per_model,])

    with tf.GradientTape(persistent=True) as tape:
      uvh = model([tt,xx,yy])
      uu, vv, hh = uvh[:,:1], uvh[:,1:2], uvh[:,2:]

    u[i*steps_per_model:(i+1)*steps_per_model,:] = uu
    v[i*steps_per_model:(i+1)*steps_per_model,:] = vv
    h[i*steps_per_model:(i+1)*steps_per_model,:] = hh    
    uy[i*steps_per_model:(i+1)*steps_per_model,:] = tape.gradient(uu, yy)
    vx[i*steps_per_model:(i+1)*steps_per_model,:] = tape.gradient(vv, xx)
    
  return u, v, h, uy, vx

# %%
# Grid where to evaluate the model
l, m, n = days+1, 150, 75
t = np.linspace(t0, tfinal, l)
x = np.linspace(lmbdleft, lmbdright, m)
y = np.linspace(thtlower, thtupper, n)
T_p, X_p, Y_p  = np.meshgrid(t,x,y, indexing='ij')

dt = t[1]-t[0]

tt = np.expand_dims(T_p.flatten(), axis=1)
xx = np.expand_dims(X_p.flatten(), axis=1)
yy = np.expand_dims(Y_p.flatten(), axis=1)

u, v, h, u_y, v_x = predict(nr_models,tt,xx,yy)
u, v, h = np.reshape(u, (l, m, n)), np.reshape(v, (l, m, n)), np.reshape(h, (l, m, n))
u_y, v_x = np.reshape(u_y, (l, m, n)), np.reshape(v_x, (l, m, n))

u_y, v_x = U*u_y/L, U*v_x/np.cos(Y_p)/L
hs = hs0(X_p, Y_p) 

# Conserved quantities
# PE
pvv = 0.5*H*h*((v_x - u_y + 2*Omega*np.sin(Y_p))/(H*(h-hs.numpy() )))**2
pv = (pvv.numpy()).sum(axis=(1,2))

# Mass
mass = H*(h-hs.numpy()).sum(axis=(1,2))

# Energy
# energy = 0.5*H*U**2*((h-hs.numpy())*(u**2+v**2))+0.5*H**2*(h-hs.numpy())**2
# energy = energy.sum(axis=(1,2))
energy2 = 0.5*H*U**2*((h-hs.numpy())*(u**2+v**2))+0.5*H**2*(h**2-hs.numpy()**2)
energy = energy2.sum(axis=(1,2))
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
plot_steps = [i for i in range(l)]
for i in plot_steps:
  plt.figure(figsize=(21,5))
  plt.subplot(131)
  plt.contourf(X_p[i,], Y_p[i,], H*h[i,], 21, cmap=plt.cm.coolwarm,
               vmin=H*h[i,].min(), vmax=H*h[i,].max())
  plt.colorbar(ticks=[5000+200*j for j in range(6)])
  plt.title('Solution for h on day{: 2.0f}'.format(i*dt))
  plt.xlabel(r'$\lambda$')
  plt.ylabel(r'$\theta$')

  plt.subplot(132)
  plt.contourf(X_p[i,], Y_p[i,], U*u[i,], 21, cmap=plt.cm.coolwarm,
               vmin=U*u[i,].min(), vmax=U*u[i,].max())
  # plt.colorbar(ticks=[20*j for j in range(6)])
  plt.colorbar()
  plt.title('Solution for u on day{: 2.0f}'.format(i*dt))
  plt.xlabel(r'$\lambda$')
  plt.ylabel(r'$\theta$')

  plt.subplot(133)
  plt.contourf(X_p[i,], Y_p[i,], U*v[i,], 21, cmap=plt.cm.coolwarm,
               vmin=U*v[i,].min(), vmax=U*v[i,].max())
  plt.colorbar()
  # plt.colorbar(ticks=[60-20*j for j in range(8)])
  plt.title('Solution for v on day{: 2.0f}'.format(i*dt))
  plt.xlabel(r'$\lambda$')
  plt.ylabel(r'$\theta$')

  plt.show()

# %%
t = np.linspace(0, tfinal, l)

plt.figure(figsize=(21, 5))

ax1 = plt.subplot(131)
rmass = (mass-mass[0])/mass[0]
plt.plot(t, rmass)
plt.xlabel('t [days]')
plt.ylabel(r'$(M-M_0)/M_0$')
plt.axis([0,tfinal,rmass.min(), rmass.max()])
plt.grid()
ax1.ticklabel_format(axis='y',style='sci',scilimits=(0,0))

ax2 = plt.subplot(132)
renergy = (energy-energy[0])/energy[0]
plt.plot(t, renergy)
# renergy2 = (energy2-energy2[0])/energy2[0]
# plt.plot(t, renergy2)
plt.xlabel('t [days]')
plt.ylabel(r'$(E-E_0)/E_0$')
plt.axis([0,tfinal,renergy.min(), renergy.max()])
plt.grid()
ax2.ticklabel_format(axis='y',style='sci',scilimits=(0,0))

ax3 = plt.subplot(133)
rpv = (pv-pv[0])/pv[0]
plt.plot(t, rpv)
plt.xlabel('t [days]')
plt.ylabel(r'$(PE-PE_0)/PE_0$')
plt.axis([0,tfinal,rpv.min(), rpv.max()])
plt.grid()
ax3.ticklabel_format(axis='y',style='sci',scilimits=(0,0))

fname = 'CLs_Williamson_' + str(williamson) + '_epochs' + str(epochs) + '.png'
plt.savefig(fname)
files.download(fname)

# %%
# Rossby-Haurwitz wave time steps needed
plot_steps = [0, 7, 14]
for i in plot_steps:
  plt.figure(figsize=(8,5))
  plt.subplot(111)
  plt.contourf(X_p[i,], Y_p[i,], H*h[i,], np.linspace(7900,11000, 31), cmap=plt.cm.coolwarm,
               vmin=H*h[i,].min(), vmax=H*h[i,].max())
  plt.colorbar(ticks=[8000+500*i for i in range(7)])
  plt.title('Solution for h on day{: 2.0f}'.format(i*dt))
  plt.xlabel(r'$\lambda$')
  plt.ylabel(r'$\theta$')
  fname = "Solution_Willimason_" + str(williamson) + '_step_' + str(i) + '_epochs' + str(epochs) + '.png'
  plt.savefig(fname)
  files.download(fname)

# %%
t = np.linspace(0, tfinal, l)

plt.figure(figsize=(8, 5))
ax1 = plt.subplot(111)
rmass = (mass-mass[0])/mass[0]
plt.plot(t, rmass)
plt.xlabel('t [days]')
plt.ylabel(r'$(M-M_0)/M_0$')
plt.axis([0,tfinal,rmass.min(), rmass.max()])
plt.grid()
plt.title('Relative change of M')
ax1.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
fname = 'M_Williamson_' + str(williamson) + '_epochs' + str(epochs) + '.png'
plt.savefig(fname)
files.download(fname)

plt.figure(figsize=(8, 5))
ax2 = plt.subplot(111)
renergy = (energy-energy[0])/energy[0]
plt.plot(t, renergy)
plt.xlabel('t [days]')
plt.ylabel(r'$(E-E_0)/E_0$')
plt.axis([0,tfinal,renergy.min(), renergy.max()])
plt.grid()
plt.title('Relative change of E')
ax2.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
fname = 'E_Williamson_' + str(williamson) + '_epochs' + str(epochs) + '.png'
plt.savefig(fname)
files.download(fname)

plt.figure(figsize=(8, 5))
ax3 = plt.subplot(111)
rpv = (pv-pv[0])/pv[0]
plt.plot(t, rpv)
plt.xlabel('t [days]')
plt.ylabel(r'$(PE-PE_0)/PE_0$')
plt.axis([0,tfinal,rpv.min(), rpv.max()])
plt.grid()
plt.title('Relative change of PE')
ax3.ticklabel_format(axis='y',style='sci',scilimits=(0,0))
fname = 'PE_Williamson_' + str(williamson) + '_epochs' + str(epochs) + '.png'
plt.savefig(fname)
files.download(fname)

# %%
# Grid where to evaluate the model
l, m, n = days*10, 150, 75
t = np.linspace(t0, tfinal, l)
x = np.linspace(lmbdleft, lmbdright, m)
y = np.linspace(thtlower, thtupper, n)
T_p, X_p, Y_p  = np.meshgrid(t,x,y, indexing='ij')

dt = t[1]-t[0]

tt = np.expand_dims(T_p.flatten(), axis=1)
xx = np.expand_dims(X_p.flatten(), axis=1)
yy = np.expand_dims(Y_p.flatten(), axis=1)

u, v, h, u_y, v_x = predict(nr_models,tt,xx,yy)
u, v, h = np.reshape(u, (l, m, n)), np.reshape(v, (l, m, n)), np.reshape(h, (l, m, n))
# u_y, v_x = np.reshape(u_y, (l, m, n)), np.reshape(v_x, (l, m, n))

filenames = []
for i in range(l):

  plt.figure(figsize=(21,5))
  plt.subplot(131)
  plt.contourf(X_p[i,], Y_p[i,], H*h[i,], 31, cmap=plt.cm.coolwarm,
               vmin=H*h[i,].min(), vmax=H*h[i,].max())
  plt.colorbar(ticks=[8000+500*i for i in range(7)])
  plt.title('Solution for h on day{: 2.0f}'.format(i*dt))
  plt.xlabel(r'$\lambda$')
  plt.ylabel(r'$\theta$')

  plt.subplot(132)
  plt.contourf(X_p[i,], Y_p[i,], U*u[i,], 31, cmap=plt.cm.coolwarm,
               vmin=U*u[i,].min(), vmax=U*u[i,].max())
  # plt.colorbar(ticks=[20*j for j in range(6)])
  plt.colorbar()
  plt.title('Solution for u on day{: 2.0f}'.format(i*dt))
  plt.xlabel(r'$\lambda$')
  plt.ylabel(r'$\theta$')

  plt.subplot(133)
  plt.contourf(X_p[i,], Y_p[i,], U*v[i,], 31, cmap=plt.cm.coolwarm,
               vmin=U*v[i,].min(), vmax=U*v[i,].max())
  plt.colorbar()
  # plt.colorbar(ticks=[60-20*j for j in range(8)])
  plt.title('Solution for v on day{: 2.0f}'.format(i*dt))
  plt.xlabel(r'$\lambda$')
  plt.ylabel(r'$\theta$')

  filename = f'{i}.png'
  filenames.append(filename)
  plt.savefig(filename)
  plt.close()

with imageio.get_writer('RossbyHaurwitz.gif', mode='I') as writer:
    for filename in filenames:
        image = imageio.imread(filename)
        writer.append_data(image)

for filename in set(filenames):
  os.remove(filename)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
